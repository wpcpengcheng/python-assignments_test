# %% [markdown]
# # Week 2: Operators & Conditionals
#
# **Topics:** arithmetic, comparison, logical operators, if/elif/else
# **Instructions:** Write your code in the cell below each question. Run (Shift+Enter) to test.

# %% [markdown]
# ---
# ### Exercise 1
# Ask the user for a test score (0-100). Print the letter grade:
# - A: 90-100
# - B: 80-89
# - C: 70-79
# - D: 60-69
# - F: below 60

# %%
# Exercise 1: Grade calculator
test_score = float(input("Enter your test score (0-100): "))

if test_score>= 60:
    print("pass")
else:
    print("fail")

# %% [markdown]
# ### Exercise 2
# Ask the user for a year. Print whether it's a leap year.
#
# Rules: divisible by 4, BUT not by 100, UNLESS also divisible by 400.
#
# Examples: 2024 → leap year, 1900 → not, 2000 → leap year

# %%
# Exercise 2: Leap year checker

print("hello")

# %% [markdown]
# ### Exercise 3
# Movie ticket pricing. Ask for age and whether they're a student (yes/no):
# - Children (under 12): $8
# - Seniors (65+): $10
# - Students: $11
# - Regular adults: $15
#
# Print the ticket price.

# %%
# Exercise 3: Movie ticket price

# %% [markdown]
# ### Exercise 4
# Write a BMI calculator. Given:
# - `weight = 70` (kg)
# - `height = 1.75` (meters)
#
# Calculate BMI = weight / height². Print the BMI and category:
# - Underweight: < 18.5
# - Normal: 18.5-24.9
# - Overweight: 25-29.9
# - Obese: 30+

# %%
# Exercise 4: BMI calculator
weight = 70
height = 1.75

# %% [markdown]
# ### Exercise 5
# FizzBuzz! Loop through numbers 1-30 and print:
# - `"FizzBuzz"` if divisible by both 3 and 5
# - `"Fizz"` if divisible by 3 only
# - `"Buzz"` if divisible by 5 only
# - The number otherwise

# %%
# Exercise 5: FizzBuzz

# %% [markdown]
# ### Exercise 6
# Ask the user for three side lengths. Determine:
# 1. Is it a valid triangle? (sum of any two sides > third side)
# 2. If valid, what type? equilateral (all equal), isosceles (two equal), or scalene (none equal)

# %%
# Exercise 6: Triangle classifier

# %% [markdown]
# ### Exercise 7
# Ask the user for a password. Check its strength:
# - **Weak**: less than 8 characters
# - **Medium**: 8+ characters but missing uppercase, lowercase, or digit
# - **Strong**: 8+ characters with at least one uppercase, one lowercase, and one digit
#
# Hint: use `.isupper()`, `.islower()`, `.isdigit()` in a loop through each character

# %%
# Exercise 7: Password strength checker

# %% [markdown]
# ### Exercise 8
# Given a number, print all of these that apply:
# - "positive" or "negative" or "zero"
# - "even" or "odd" (skip for zero)
# - "divisible by 5" (if applicable)
#
# Example: 20 → "positive, even, divisible by 5"

# %%
# Exercise 8: Number classifier
number = 20
